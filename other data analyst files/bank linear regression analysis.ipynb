# %%
import matplotlib.pyplot as plot
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# my data set wasnt well formatted on the excel sheet. 
# data was separated with ";" and ","
# chnaging the way it was displayed for 'settings' had no effect
# i had to use it like that. I had to clean the data


data = pd.read_csv('../bank/bank(unstructured).csv')
headers = data.head()

# %%
def clean_data(data):
    for i in data:
        removeQote = i.replace('"', '')
    return removeQote.replace(";", ',').split(',')
clean_data(data)
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
dataset_len = len(dataset)
def get_and_clean_row():
    dict = {'data':[]}
    for index in range(0, dataset_len):
        row = {index:clean_data(dataset.iloc[index].values)}
        dict['data'].append(row)
    return dict
        
    
columns = clean_data(headers)
rows = get_and_clean_row()

def bank_data():
    age = []
    job = []
    marital = []
    education = []
    default = []
    balance = []
    housing= []
    loan= []
    contact = []
    day = []
    month = []
    duration = []
    campaign = []
    pdays = []
    previous = []
    poutcome = []
    y = []

    for i in range(0, dataset_len):
        age.append(rows['data'][i][i][0])
        job.append(rows['data'][i][i][1])
        marital.append(rows['data'][i][i][2])
        education.append(rows['data'][i][i][3])
        default.append(rows['data'][i][i][4])
        balance.append(rows['data'][i][i][5])
        loan.append(rows['data'][i][i][6])
        housing.append(rows['data'][i][i][7])
        contact.append(rows['data'][i][i][8])
        day.append(rows['data'][i][i][9])
        month.append(rows['data'][i][i][10])
        duration.append(rows['data'][i][i][11])
        campaign.append(rows['data'][i][i][12])
        pdays.append(rows['data'][i][i][13])
        previous.append(rows['data'][i][i][14])
        poutcome.append(rows['data'][i][i][15])
        y.append(rows['data'][i][i][16])
    
    results = {
            'age': pd.Series(age),
             'job': pd.Series(job),
             'marital': pd.Series(marital),
             'education': pd.Series(education),
             'default': pd.Series(default),
             'balance': pd.Series(balance),
             'housing': pd.Series(housing),
             'loan': pd.Series(loan),
             'contact': pd.Series(contact),
             'day': pd.Series(day),
             'month': pd.Series(month),
             'duration': pd.Series(duration),
             'campaign': pd.Series(campaign),
             'pdays': pd.Series(pdays),
             'previous': pd.Series(previous),
             'poutcome': pd.Series(poutcome),
             'y': pd.Series(y)}
    return results

# %%
cleanDataSet = pd.DataFrame(bank_data())
cleanDataSet
# Out:
#      age balance campaign    contact day default duration  education housing  \
# 0     30    1787        1   cellular  19      no       79    primary      no
# 1     33    4789        1   cellular  11      no      220  secondary     yes
# 2     35    1350        1   cellular  16      no      185   tertiary      no
# 3     30    1476        4    unknown   3      no      199   tertiary     yes
# 4     59       0        1    unknown   5      no      226  secondary      no
# 5     35     747        2   cellular  23      no      141   tertiary      no
# 6     36     307        1   cellular  14      no      341   tertiary      no
# 7     39     147        2   cellular   6      no      151  secondary      no
# 8     41     221        2    unknown  14      no       57   tertiary      no
# 9     43     -88        1   cellular  17      no      313    primary     yes
# 10    39    9374        1    unknown  20      no      273  secondary      no
# ...

# %%
x = pd.factorize(cleanDataSet.iloc[:, 0].values)[0].reshape(-1, 1)
x
# Out:
# array([[ 0],
#        [ 1],
#        [ 2],
#        ...,
#        [31],
#        [39],
#        [16]])

# %%
y = cleanDataSet.iloc[:, 1] # balance
y
# Out:
# 0        1787
# 1        4789
# 2        1350
# 3        1476
# 4           0
# 5         747
# 6         307
# 7         147
# 8         221
# 9         -88
# 10       9374
# 11        264
# 12       1109
# 13        502
# 14        360
# 15        194
# 16       4073
# 17       2317
# 18       -221
# 19        132
# 20          0
# 21         16
# 22        106
# 23         93
# 24        543
# 25       5883
# 26        627
# 27        696
# 28        784
# 29        105
#         ...
# 4491        0
# 4492      309
# 4493        0
# 4494      668
# 4495     1175
# 4496      363
# 4497       38
# 4498     1183
# 4499      942
# 4500     4196
# 4501      297
# 4502      -91
# 4503      362
# 4504     1080
# 4505      620
# 4506     -166
# 4507      288
# 4508      642
# 4509     2506
# 4510      566
# 4511      668
# 4512     1100
# 4513      322
# 4514     1205
# 4515      473
# 4516     -333
# 4517    -3313
# 4518      295
# 4519     1137
# 4520     1136
# ...

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.33, random_state = 42)

# %%
linearRegressor = LinearRegression()

# %%
linearRegressor.fit(xTrain, yTrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plot.scatter(xTrain, yTrain, color="red")
plot.plot(xTrain, linearRegressor.predict(xTrain), color = 'blue')
plot.title("Age vs Account balance (training set)")
plot.xlabel('age')
plot.ylabel('account balance')
plot.show()

# %%
plot.scatter(xTest,yTest, color= 'red')
plot.plot(xTrain, linearRegressor.predict(xTrain), color = 'blue')
plot.title("Age vs Account balance (training set)")
plot.xlabel('age')
plot.ylabel('account balance')
plot.show()
